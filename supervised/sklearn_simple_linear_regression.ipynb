# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
temperature = np.array(range(60, 100, 2))
temperature = temperature.reshape(-1, 1)
sales = [65, 58, 46, 45, 44, 42, 40, 40, 36, 38, 38, 28, 30, 22, 27, 25, 25, 20, 15, 5]

# %%
plt.plot(temperature, sales, 'o')

# %%
plt.plot(temperature, sales, 'o')

line_fitter = LinearRegression()
line_fitter.fit(temperature, sales)

sales_predict = line_fitter.predict(temperature)

plt.plot(temperature, sales_predict)
plt.show()

# %%
y_predicted = line_fitter.predict(temperature)
print(y_predicted)
# Out:
# [56.34285714 54.03834586 51.73383459 49.42932331 47.12481203 44.82030075
#  42.51578947 40.2112782  37.90676692 35.60225564 33.29774436 30.99323308
#  28.6887218  26.38421053 24.07969925 21.77518797 19.47067669 17.16616541
#  14.86165414 12.55714286]
